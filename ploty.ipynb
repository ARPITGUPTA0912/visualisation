# %%
import  seaborn as sns
import plotly.graph_objects as go
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Q1. Load the "titanic" dataset using the load_dataset function of seaborn. Use Plotly express to plot a scatter plot for age and fare columns in the titanic dataset.

# %%
df1 = sns.load_dataset("titanic")

# %%
df1.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import plotly.express as px


fig = px.scatter(df1, x="age", y="fare", 
                title="titanic")
fig.show()

# %% [markdown]
# Q2. Using the tips dataset in the Plotly library, plot a box plot using Plotly express.

# %%
df2 = sns.load_dataset('tips')

# %%
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig = px.box(df2,x='sex', y ='tip', title="tips data analogy")
fig.show()

# %% [markdown]
# Q3. Using the tips dataset in the Plotly library, Plot a histogram for x= "sex" and y="total_bill" column in
# the tips dataset. Also, use the "smoker" column with the pattern_shape parameter and the "day"
# column with the color parameter.

# %%
fig = px.histogram(df2,x='sex', y ='total_bill', title="tips data analogy",pattern_shape='smoker',color='day' )
fig.show()

# %% [markdown]
# Q4. Using the iris dataset in the Plotly library, Plot a scatter matrix plot, using the "species" column for
# the color parameter.

# %%
df4= px.data.iris()

# %%
df4.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %%
fig= px.scatter_matrix(df4, color='species')
fig.show()

# %% [markdown]
# Q5. What is Distplot? Using Plotly express, plot a distplot.

# %% [markdown]
# A distribution plot, also known as a Distplot, displays the variation in data distribution. The total distribution of continuous data variables

# %%
import plotly.figure_factory as ff

# %%
df1= [df4['sepal_length'],df4['sepal_width']]

# %%
ff.create_distplot(df1, group_labels=['sepal_lengths','sepal_width'])
