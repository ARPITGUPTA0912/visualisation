# %%
print ("Matplotlib Task\n")
q1 ="""Q1: What is Matplotlib? Why is it used ? Name five plots that can be plotted using the Pyplot 
module of Matplotlib.\n"""
print (q1)
ans1 = '''Matplotlib is a cross-platform, data visualization and graphical plotting library (histograms,
scatter plots, bar charts, etc) for Python and its numerical extension NumPy.
it offers a viable open source alternative to MATLAB. Developers can also use matplotlib’s APIs 
(Application Programming Interfaces) to embed plots in GUI applications.
Five plots that can be plotted using the Pyplot module of Matplotlib-
Bar Graph using matplotlib.pyplot.bar
Scatter Chart using matplotlib.pyplot.scatter
Pie Plot using matplotlib.pyplot.pie
Histogram using matplotlib.pyplot.hist
Line Plot and Subplots using matplotlib.pyplot.plot
Scatter Plot using matplotlib.
'''
print(ans1)
# Out:
# Matplotlib Task
#
# Q1: What is Matplotlib? Why is it used ? Name five plots that can be plotted using the Pyplot
# module of Matplotlib.
#
# Matplotlib is a cross-platform, data visualization and graphical plotting library (histograms,
# scatter plots, bar charts, etc) for Python and its numerical extension NumPy.
# it offers a viable open source alternative to MATLAB. Developers can also use matplotlib’s APIs
# (Application Programming Interfaces) to embed plots in GUI applications.
# Five plots that can be plotted using the Pyplot module of Matplotlib-
# Bar Graph using matplotlib.pyplot.bar
# Scatter Chart using matplotlib.pyplot.scatter
# Pie Plot using matplotlib.pyplot.pie
# Histogram using matplotlib.pyplot.hist
# Line Plot and Subplots using matplotlib.pyplot.plot
# Scatter Plot using matplotlib.

# %%
q2='''Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
plot a scatter plot.'''
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

print(q2)
ans2 = '''We can implement the scatter (previously called XY) plots while comparing various data variables to determine the connection
between dependent and independent variables'''
print(ans2)
plt.scatter(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("random")
plt.show()
# Out:
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# We can implement the scatter (previously called XY) plots while comparing various data variables to determine the connection
# between dependent and independent variables

# %%
q3='''Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
Use the following data:\n'''
ans3="""subplot() function adds subplot to a current figure at the specified grid position. It is
similar to the subplots() function however unlike subplots() it adds one subplot at a time. So to
create multiple plots you will need several lines of code with the subplot() function"""
print(q3)
print(ans3)
x1= np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])
x4= np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

plt.subplot(2,2,1)
plt.plot(x1,y1, label = 'line1')
plt.subplot(2,2,2)
plt.plot(x2,y2,label='line2')
plt.subplot(2,2,3)
plt.plot(x3,y3,label='line3')

plt.subplot(2,2,4)
plt.plot(x4,y4,label='line4')
plt.show()
# Out:
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
#
# subplot() function adds subplot to a current figure at the specified grid position. It is
# similar to the subplots() function however unlike subplots() it adds one subplot at a time. So to
# create multiple plots you will need several lines of code with the subplot() function

# %%
ans= 'If we plot in asingle graph above four lines\n'
print(ans)
plt.plot(x1,y1, label = 'line1')
plt.plot(x2,y2,label='line2')
plt.plot(x3,y3,label='line3')
plt.plot(x4,y4,label='line4')

plt.show()
# Out:
# If we plot in asingle graph above four lines

# %%
q4='''Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a
horizontal bar plot.'''
print(q4)
ans4 ='''A barplot (or barchart) is one of the most common types of graphic. It shows the
relationship between a numeric and a categoric variable. Each entity of the categoric variable is
represented as a bar. The size of the bar represents its numeric value.'''
print(ans4)
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.subplot(2,1,2)
plt.bar(company, profit)
plt.subplot(2,1,1)
plt.barh(company, profit)
plt.show()
# Out:
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a
# horizontal bar plot.
# A barplot (or barchart) is one of the most common types of graphic. It shows the
# relationship between a numeric and a categoric variable. Each entity of the categoric variable is
# represented as a bar. The size of the bar represents its numeric value.

# %%
q5 ='Q5: What is a box plot? Why is it used? Using the following data plot a box plot.'
print(q5)
ans5='''Box plots provide a quick visual summary of the variability of values in a dataset. They
show the median, upper and lower quartiles, minimum and maximum values, and any outliers in the
dataset. Outliers can reveal mistakes or unusual occurrences in data.'''
print(ans5)
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
plt.subplot(2,1,1)
plt.boxplot(box1)

plt.subplot(2,1,2)
plt.boxplot(box2)
plt.show()
# Out:
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# Box plots provide a quick visual summary of the variability of values in a dataset. They
# show the median, upper and lower quartiles, minimum and maximum values, and any outliers in the
# dataset. Outliers can reveal mistakes or unusual occurrences in data.
